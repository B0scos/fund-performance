# %%
import pandas as pd
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score

# %%
train_path = r'..\data\splitted_features\train.parquet'
test_path = r'..\data\splitted_features\test.parquet'
val_path =  r'..\data\splitted_features\validation.parquet'

# %%
train_df = pd.read_parquet(train_path)
test_df = pd.read_parquet(test_path)
val_df = pd.read_parquet(val_path)

# %%
print(train_df.shape)
print(test_df.shape)
print(val_df.shape)
# Out:
# (2052, 16)
# (2434, 16)
# (2181, 16)

# %%
train_df.columns
# Out:
# Index(['mean_return', 'std_return', 'max_drawdown', 'avg_drawdown',
#        'avg_gross_by_net', 'avg_inflow', 'avg_redemption', 'avg_shareholders',
#        'mean_std_5', 'mean_std_10', 'mean_std_15', 'std_std_5', 'std_std_10',
#        'std_std_15', 'sharpe', 'ret_by_DD'],
#       dtype='object')

# %%
drop_cols = ['avg_inflow',  'avg_redemption',  'avg_shareholders', 'avg_gross_by_net', 'max_drawdown']

train_df = train_df.drop(drop_cols, axis=1)
test_df = test_df.drop(drop_cols, axis=1)
val_df = val_df.drop(drop_cols, axis=1)

# %%
train_df.corr()
# Out:
#               mean_return  std_return  avg_drawdown  mean_std_5  mean_std_10  \
# mean_return      1.000000    0.565498      0.008116    0.422081     0.333811
# std_return       0.565498    1.000000      0.706815    0.761329     0.618494
# avg_drawdown     0.008116    0.706815      1.000000    0.616069     0.508835
# mean_std_5       0.422081    0.761329      0.616069    1.000000     0.838978
# mean_std_10      0.333811    0.618494      0.508835    0.838978     1.000000
# mean_std_15      0.291887    0.534712      0.431620    0.731404     0.876713
# std_std_5        0.121601    0.362480      0.291334    0.713683     0.627812
# std_std_10       0.087925    0.255423      0.196735    0.467122     0.707824
# std_std_15       0.080228    0.197047      0.146061    0.357744     0.544200
# sharpe           0.026350   -0.042229     -0.055563   -0.034503    -0.021693
# ret_by_DD       -0.018476   -0.022600     -0.028550   -0.033177    -0.028628
#
#               mean_std_15  std_std_5  std_std_10  std_std_15    sharpe  \
# mean_return      0.291887   0.121601    0.087925    0.080228  0.026350
# std_return       0.534712   0.362480    0.255423    0.197047 -0.042229
# avg_drawdown     0.431620   0.291334    0.196735    0.146061 -0.055563
# mean_std_5       0.731404   0.713683    0.467122    0.357744 -0.034503
# mean_std_10      0.876713   0.627812    0.707824    0.544200 -0.021693
# mean_std_15      1.000000   0.554265    0.638446    0.699033 -0.010078
# std_std_5        0.554265   1.000000    0.692600    0.550240 -0.041783
# std_std_10       0.638446   0.692600    1.000000    0.814226 -0.013874
# std_std_15       0.699033   0.550240    0.814226    1.000000  0.001178
# sharpe          -0.010078  -0.041783   -0.013874    0.001178  1.000000
# ret_by_DD       -0.029036  -0.011456   -0.022320   -0.020757  0.009919
#
#               ret_by_DD
# mean_return   -0.018476
# std_return    -0.022600
# avg_drawdown  -0.028550
# mean_std_5    -0.033177
# mean_std_10   -0.028628
# mean_std_15   -0.029036
# std_std_5     -0.011456
# std_std_10    -0.022320
# std_std_15    -0.020757
# sharpe         0.009919
# ret_by_DD      1.000000

# %%
scaler = StandardScaler()
behavior_cols = train_df.columns
X_train = scaler.fit_transform(train_df[behavior_cols])
X_val   = scaler.transform(test_df[behavior_cols])
X_test  = scaler.transform(val_df[behavior_cols])

# %%
pca = PCA(n_components=X_train.shape[1])
pca.fit(train_df)
# Out:
# PCA(n_components=11)

# %%
train_df_pca = pca.transform(X_train)
val_df_pca = pca.transform(X_test)
test_df_pca = pca.transform(X_val)
# Out:
# c:\Users\ferre\OneDrive\Área de Trabalho\new projects\.venv\lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but PCA was fitted with feature names
#   warnings.warn(
# c:\Users\ferre\OneDrive\Área de Trabalho\new projects\.venv\lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but PCA was fitted with feature names
#   warnings.warn(
# c:\Users\ferre\OneDrive\Área de Trabalho\new projects\.venv\lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but PCA was fitted with feature names
#   warnings.warn(

# %%
behavior_cols = [
    "mean_return",
    "std_return",
    "avg_drawdown",
    "max_drawdown"
]


X_train = train_df_pca
X_val   = test_df_pca
X_test  = val_df_pca

# %%
results = {}
for k in [2, 3, 4, 5, 6]:
    km = KMeans(n_clusters=k, random_state=42, n_init="auto")
    labels = km.fit_predict(X_train)
    score = silhouette_score(X_train, labels)
    results[k] = score

print("Silhouette scores:", results)

# Pick the best K (highest silhouette)
best_k = max(results, key=results.get)
print("Best k:", best_k)
# Out:
# Silhouette scores: {2: 0.40024134023798846, 3: 0.320874164331956, 4: 0.24840026151288314, 5: 0.23143873360659847, 6: 0.23713929407980233}
# Best k: 2

# %%
kmeans = KMeans(n_clusters=best_k, random_state=0, n_init="auto")
train_clusters = kmeans.fit_predict(X_train)
val_clusters   = kmeans.predict(X_val)
test_clusters  = kmeans.predict(X_test)

# %%
# Attach back to fund ids
train_clustered = train_df.copy()
train_clustered["cluster"] = train_clusters

val_clustered = test_df.copy()
val_clustered["cluster"] = val_clusters

test_clustered = val_df.copy()
test_clustered["cluster"] = test_clusters

print("\nTrain cluster summary:")
print(train_clustered.groupby("cluster").mean()['sharpe'])

print("\nTest cluster summary:")
print(test_clustered.groupby("cluster").mean()['sharpe'])

print("\n Val cluster summary:")
print(val_clustered.groupby("cluster").mean()['sharpe'])
# Out:
# Train cluster summary:
# cluster
# 0    0.366106
# 1    0.314001
# Name: sharpe, dtype: float64
#
# Test cluster summary:
# cluster
# 0    0.483628
# 1    0.362840
# Name: sharpe, dtype: float64
#
#  Val cluster summary:
# cluster
# 0    1.250617
# 1    0.324418
# Name: sharpe, dtype: float64

# %%
print(train_clustered["cluster"].value_counts())
# Out:
# cluster
# 0    1568
# 1     484
# Name: count, dtype: int64

# %%
cluster_number = 1
outlier_fund = train_clustered[train_clustered["cluster"] == cluster_number]
outlier_fund
# Out:
#                     mean_return  std_return  avg_drawdown  mean_std_5  \
# fund_cnpj
# 00.398.561/0001-90     0.002213    0.010604      0.006428    0.005003
# 00.524.617/0001-06     0.000043    0.006948      0.011628    0.004639
# 00.819.858/0001-82     0.000351    0.000440      0.000024    0.005887
# 00.819.880/0001-22     0.000019    0.006996      0.011816    0.004993
# 01.063.897/0001-65     0.002873    0.009296      0.002888    0.006821
# ...                         ...         ...           ...         ...
# 53.633.558/0001-70     0.002302    0.008503      0.005632    0.005852
# 55.234.165/0001-10     0.002461    0.008504      0.005428    0.006039
# 63.375.216/0001-51     0.002515    0.007037      0.003674    0.004261
# 74.326.471/0001-20     0.000489    0.005725      0.007687    0.004597
# 97.519.703/0001-62     0.000429    0.000347      0.000069    0.004665
#
#                     mean_std_10  mean_std_15  std_std_5  std_std_10  \
# fund_cnpj
# 00.398.561/0001-90     0.004758     0.005362   0.004233    0.003662
# 00.524.617/0001-06     0.005341     0.006278   0.002527    0.003074
# 00.819.858/0001-82     0.005923     0.005382   0.009268    0.006903
# 00.819.880/0001-22     0.004578     0.005701   0.003775    0.002784
# 01.063.897/0001-65     0.005718     0.005781   0.006128    0.004475
# ...                         ...          ...        ...         ...
# 53.633.558/0001-70     0.005811     0.005577   0.007154    0.005085
# 55.234.165/0001-10     0.005152     0.004965   0.007144    0.005418
# 63.375.216/0001-51     0.005283     0.004618   0.002369    0.006309
# 74.326.471/0001-20     0.005591     0.005355   0.002612    0.004965
# 97.519.703/0001-62     0.005609     0.005998   0.004711    0.005607
#
#                     std_std_15    sharpe  ret_by_DD  cluster
# fund_cnpj
# 00.398.561/0001-90    0.004680  0.208674   0.344269        1
# 00.524.617/0001-06    0.004822  0.006135   0.003666        1
# 00.819.858/0001-82    0.005466  0.797396  14.903396        1
# 00.819.880/0001-22    0.005409  0.002713   0.001606        1
# 01.063.897/0001-65    0.003394  0.309120   0.994910        1
# ...                        ...       ...        ...      ...
# 53.633.558/0001-70    0.003997  0.270750   0.408792        1
# 55.234.165/0001-10    0.004262  0.289438   0.453436        1
# 63.375.216/0001-51    0.005074  0.357366   0.684440        1
# 74.326.471/0001-20    0.004188  0.085487   0.063668        1
# 97.519.703/0001-62    0.005560  1.235970   6.213721        1
#
# [484 rows x 12 columns]
